# %%
import TSM
import networkx as nx

# %%
G = nx.Graph(nx.read_gml('test_data/case1.gml'))

# %%
planar = TSM.Planarization(G)
ortho = TSM.Orthogonalization(planar)
compa = TSM.Compaction(ortho)

# %%
compa.draw(node_size=20)
